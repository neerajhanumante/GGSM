# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

import seaborn as sns

import os 
cwd =  os.getcwd()
print(cwd)
import warnings
warnings.filterwarnings('ignore')
from matplotlib import rc,rcParams
rc('font', weight='normal', size='14')
rc('font',family='serif')
# Out:
# C:\Users\Apoorva\OneDrive\Desktop\GGSM-Part1

# %%
plt.rcParams['axes.linewidth'] = 0.75
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

# %%
proj1 = pd.read_csv('C:/Users/Apoorva/OneDrive/Desktop/GGSM-Part1/Main GGSM - plotting code/output/scenario_1_2.csv')
proj1= proj1.iloc[60:210, 0:109]
proj1= proj1.iloc[::5, 0:109]
proj1.head()
# Out:
#     Time        P1         P2        P3        H1        H2        H3  \
# 60  2020  4.384947  13.102808  1.113106  3.842468  0.432496  3.438647
# 65  2025  4.384874  13.071865  1.115294  3.842468  0.432326  3.437397
# 70  2030  4.384819  13.039916  1.117569  3.842468  0.432131  3.436076
# 75  2035  4.384778  13.006039  1.119987  3.842468  0.431881  3.434632
# 80  2040  4.384749  12.970171  1.122562  3.842468  0.431589  3.433074
#
#           C1        C2        numHH  ...   P3_sce2   H1_sce2   H2_sce2  \
# 60  2.938413  1.245263  82451.31018  ...  1.113106  3.842468  0.432496
# 65  2.930926  1.242956  87720.31018  ...  1.115531  3.842468  0.432293
# 70  2.923253  1.240572  91724.31018  ...  1.118159  3.842468  0.432061
# 75  2.915212  1.238045  94644.31018  ...  1.120830  3.842468  0.431782
# 80  2.906743  1.235371  96717.31018  ...  1.123602  3.842468  0.431454
#
#      H3_sce2   C1_sce2   C2_sce2   numHH_sce2  C_Emission_sce2      GDP_sce2  \
# ...

# %%
un = pd.read_csv('C:/Users/Apoorva/OneDrive/Desktop/GGSM-Part1/Main GGSM - plotting code/output/UN comparison.csv')
un= un.iloc[0:167, 0:16]
un= un.iloc[::5, 0:16]
un.head()
# Out:
#     Time          Pop  Pop_world_med  Pop_world_up  Pop_world_low  Pop_exp_mod
# 0   1950  25364.31018          25364       25364.0        25364.0  25364.31018
# 5   1955  27545.31018          27730       27730.0        27730.0  27545.31018
# 10  1960  30037.31018          30349       30349.0        30349.0  30037.31018
# 15  1965  32920.31018          33396       33396.0        33396.0  32920.31018
# 20  1970  36216.31018          37004       37004.0        37004.0  36216.31018

# %%
#fit.plot.scatter(x='Time', y= 'Pop', marker ='p', markerfacecolor='blue', markeredgecolor='blue')
#create scatter plot
figsize = (6,3)
ax = un.plot(kind='line', x="Time", y="Pop", color='red')    
un.plot(kind='line', x="Time", y="Pop_exp_mod", color='seagreen',ax=ax)    
un.plot(kind='line', x="Time", y="Pop_world_med", color='blue',ax=ax)    
un.plot(kind='line', x="Time", y="Pop_world_up", style='--',color='grey',ax=ax)    
un.plot(kind='line', x="Time", y="Pop_world_low", style='--',color='grey',ax=ax) 
ax.set_xlim(right=2120)
ax.set_xlabel("Time (Years)")
ax.set_ylabel("Global Population(Hundred Thousand)")
ax.legend(["GGSM- Scenario 1","GGSM- Scenario 2","UN Medium Variant","UN Upper Variant","UN Lower Variant"],fancybox=True, framealpha=0)
plt.savefig('fig9.jpeg',dpi = 300,  bbox_inches='tight')
plt.show()

# %%
df = pd.read_csv('C:/Users/Apoorva/OneDrive/Desktop/GGSM-Part1/Main GGSM - plotting code/output/SectorWiseCarbon.csv')
df1= df.iloc[0:200,0:5]
df1= df.iloc[::5,0:5]

df1.head()
# Out:
#     Year    P1_wo_bio    IS_wo_bio     EE_wo_bio   Hum_wo_bio
# 0   1960  1742876.150  3960504.148  7.231695e+06  6305777.704
# 5   1965  1948801.856  4240606.216  7.868905e+06  6910791.788
# 10  1970  2192558.907  4539413.763  8.581909e+06  7602536.458
# 15  1975  2482763.581  4853575.630  9.372440e+06  8395081.808
# 20  1980  2824129.385  5172030.246  1.024719e+07  9289267.844

# %%
sns.set_palette("colorblind")

from PIL import Image
figsize=(10, 5)
x1= df1[['Year','P1_wo_bio', 'IS_wo_bio', 'EE_wo_bio','Hum_wo_bio']]
x1.plot.area(x='Year')
plt.xlabel("Year")
plt.ylabel("Carbon Emissions (kt)") 
plt.legend(["Agriculture","Industry","Energy","Residential and Transportation"], prop={'size': 7.5}, fancybox=True, framealpha=0.5)
plt.xlim(left=1960,right=2150)
plt.savefig('fig8.jpeg', dpi = 300,  bbox_inches='tight')

plt.show()

# %%
proj3 = pd.read_csv('C:/Users/Apoorva/OneDrive/Desktop/GGSM-Part1/Main GGSM - plotting code/output/scenario_3_4.csv')
proj3= proj3.iloc[61:210, 0:109]
#proj3= proj3.iloc[::5, 0:109]
proj3.head()
# Out:
#     Time   P1_sce3    P2_sce3   P3_sce3   H1_sce3   H2_sce3   H3_sce3  \
# 61  2021  4.380913  13.088019  1.111760  3.842468  0.433047  3.444663
# 62  2022  4.380743  13.054168  1.114745  3.842468  0.432308  3.440609
# 63  2023  4.380570  13.018953  1.117249  3.842468  0.431954  3.439156
# 64  2024  4.380396  12.982684  1.119811  3.842468  0.431647  3.437753
# 65  2025  4.380219  12.945302  1.122455  3.842468  0.431299  3.436317
#
#      C1_sce3   C2_sce3   numHH_sce3  ...   P3_sce4   H1_sce4   H2_sce4  \
# 61  2.920241  1.245135  83590.31018  ...  1.111795  3.842468  0.433029
# 62  2.912012  1.242783  84682.31018  ...  1.114831  3.842468  0.432283
# 63  2.903081  1.240159  85732.31018  ...  1.117395  3.842468  0.431921
# 64  2.893799  1.237452  86744.31018  ...  1.120021  3.842468  0.431602
# 65  2.884228  1.234656  87720.31018  ...  1.122736  3.842468  0.431239
#
#      H3_sce4   C1_sce4   C2_sce4   numHH_sce4  C_Emission_sce4      GDP_sce4  \
# ...

# %%
fig, ax = plt.subplots(4, 3, figsize = (20,20))
#ax.set_xticklabels(xvalues, fontsize=16)
proj1.plot(kind='line', x="Time", y="C1", color='r',ax=ax[0, 0])
proj1.plot(kind='line', x="Time", y="C1_sce2", color='seagreen',ax=ax[0, 0])    
ax[0, 0].set_xlabel("Time(Years)")
ax[0, 0].set_ylabel("Carnivores C1")
ax[0, 0].legend(["Scenario 1","Scenario 2"])
#ax[0, 0].set_title('C1')
proj1.plot(kind='line', x="Time", y="C2", color='r',ax=ax[0, 1])    
proj1.plot(kind='line', x="Time", y="C2_sce2", color='seagreen',ax=ax[0, 1])    
ax[0, 1].set_xlabel("Time(Years)")
ax[0, 1].set_ylabel("Carnivores C2")
ax[0, 1].legend(["Scenario 1","Scenario 2"])
#ax[0, 1].set_title('C2')
proj1.plot(kind='line', x="Time", y="H1", color='r',ax=ax[0, 2])    
proj1.plot(kind='line', x="Time", y="H1_sce2", color='seagreen',ax=ax[0, 2])    
ax[0, 2].set_xlabel("Time(Years)")
ax[0, 2].set_ylabel("Herbivores H1")
ax[0, 2].legend(["Scenario 1","Scenario 2"])
ax[0, 2].set_ylim(bottom=3,top=4)
#ax[0,2].set_title('H1')

ax[1,0]=proj1.plot(kind='line', x="Time", y="H2", color='r',ax=ax[1,0])    
proj1.plot(kind='line', x="Time", y="H2_sce2", color='seagreen',ax=ax[1,0])    
ax[1,0].set_xlabel("Time(Years)")
ax[1,0].set_ylabel("Herbivores H2")
ax[1,0].legend(["Scenario 1","Scenario 2"])
#ax[1,0].set_title('H2')

ax[1, 1]=proj1.plot(kind='line', x="Time", y="H3", color='r',ax=ax[1, 1])    
proj1.plot(kind='line', x="Time", y="H3_sce2", color='seagreen',ax=ax[1, 1])    
ax[1, 1].set_xlabel("Time(Years)")
ax[1, 1].set_ylabel("Herbivores H3")
ax[1, 1].legend(["Scenario 1","Scenario 2"])
#ax[1,1].set_title('H3')

ax[1, 2]=proj1.plot(kind='line', x="Time", y="P1", color='r',ax=ax[1, 2])    
proj1.plot(kind='line', x="Time", y="P1_sce2", color='seagreen',ax=ax[1, 2])    
ax[1, 2].set_xlabel("Time(Years)")
ax[1, 2].set_ylabel("Primary Producers P1")
ax[1, 2].legend(["Scenario 1","Scenario 2"])
#ax[1,2].set_title('P1')


ax[2, 0]=proj1.plot(kind='line', x="Time", y="P2", color='r',ax=ax[2, 0])    
proj1.plot(kind='line', x="Time", y="P2_sce2", color='seagreen',ax=ax[2, 0])    
ax[2, 0].set_xlabel("Time(Years)")
ax[2, 0].set_ylabel("Primary Producers P2")
ax[2, 0].legend(["Scenario 1","Scenario 2"])
#ax[2,0].set_title('P2')

ax[2, 1]=proj1.plot(kind='line', x="Time", y="P3", color='r',ax=ax[2, 1])    
proj1.plot(kind='line', x="Time", y="P3_sce2", color='seagreen',ax=ax[2, 1])    
ax[2, 1].set_xlabel("Time(Years)")
ax[2, 1].set_ylabel("Primary Producers P3")
ax[2, 1].legend(["Scenario 1","Scenario 2"])
#ax[2,1].set_title('P3')

ax[2, 2]=proj1.plot(kind='line', x="Time", y="C_Emission", color='r',ax=ax[2, 2])    
proj1.plot(kind='line', x="Time", y="C_Emission_sce2", color='seagreen',ax=ax[2, 2])    
ax[2, 2].set_xlabel("Time(Years)")
ax[2, 2].set_ylabel("Carbon Emissions(kt)")
ax[2, 2].legend(["Scenario 1","Scenario 2"])
#ax[2,2].set_title('CO2')

ax[3, 0]=proj1.plot(kind='line', x="Time", y="GDP", color='r',ax=ax[3, 0])    
proj1.plot(kind='line', x="Time", y="GDP_sce2", color='seagreen',ax=ax[3, 0])    
ax[3, 0].set_xlabel("Time(Years)")
ax[3, 0].set_ylabel("GDP (US $)")
ax[3, 0].legend(["Scenario 1","Scenario 2"])
#ax[3,0].set_title('GDP')

ax[3, 1]=proj1.plot(kind='line', x="Time", y="numHH", color='r',ax=ax[3, 1])    
proj1.plot(kind='line', x="Time", y="numHH_sce2", color='seagreen',ax=ax[3, 1])    
ax[3, 1].set_xlabel("Time(Years)")
ax[3, 1].set_ylabel("Human Population (Hundred Thousand)")
ax[3, 1].legend(["Scenario 1","Scenario 2"])
#ax[3,1].set_title('Humans')

ax[3, 2]=proj1.plot(kind='line', x="Time", y="N_Emission", color='r',ax=ax[3, 2])    
proj1.plot(kind='line', x="Time", y="N_Emission_sce2", color='seagreen',ax=ax[3, 2])    
ax[3, 2].set_xlabel("Time(Years)")
ax[3, 2].set_ylabel("Nitrogen Emissions(1000 MT CO2EQ)")
ax[3, 2].set_ylabel("Nitrogen Emissions(1000 MT CO2EQ)")

ax[3, 2].legend(["Scenario 1","Scenario 2"])
#ax[3,2].set_title('Nitrous Oxide Emissions')
plt.tight_layout()

plt.savefig('fig7.jpeg', dpi=600);
plt.show()

# %%
sns.set_palette("bright")
fig, ax = plt.subplots(4, 3, figsize = (20,20))
proj3.plot(kind='line', x="Time", y="C1_sce3", ax=ax[0, 0])
proj3.plot(kind='line', x="Time", y="C1_sce4",ax=ax[0, 0])    
ax[0, 0].set_xlabel("Time(Years)")
ax[0, 0].set_ylabel("Carnivores C1")
ax[0, 0].legend(["Scenario 3","Scenario 4"])

proj3.plot(kind='line', x="Time", y="C2_sce3", ax=ax[0, 1])    
proj3.plot(kind='line', x="Time", y="C2_sce4",ax=ax[0, 1])    
ax[0, 1].set_xlabel("Time(Years)")
ax[0, 1].set_ylabel("Carnivores C2")
ax[0, 1].legend(["Scenario 3","Scenario 4"])

proj3.plot(kind='line', x="Time", y="H1_sce3", ax=ax[0, 2])    
proj3.plot(kind='line', x="Time", y="H1_sce4",ax=ax[0, 2])    
ax[0, 2].set_xlabel("Time(Years)")
ax[0, 2].set_ylabel("Herbivores H1")
ax[0, 2].legend(["Scenario 3","Scenario 4"])


ax[1,0]=proj3.plot(kind='line', x="Time", y="H2_sce3", ax=ax[1,0])    
proj3.plot(kind='line', x="Time", y="H2_sce4",ax=ax[1,0])    
ax[1,0].set_xlabel("Time(Years)")
ax[1,0].set_ylabel("Herbivores H2")
ax[1,0].legend(["Scenario 3","Scenario 4"])
ax[1,0].set_title('H2')

ax[1, 1]=proj3.plot(kind='line', x="Time", y="H3_sce3", ax=ax[1, 1])    
proj3.plot(kind='line', x="Time", y="H3_sce4",ax=ax[1, 1])    
ax[1, 1].set_xlabel("Time(Years)")
ax[1, 1].set_ylabel("Herbivores H3")
ax[1, 1].legend(["Scenario 3","Scenario 4"])
ax[1,1].set_title('H3')

ax[1, 2]=proj3.plot(kind='line', x="Time", y="P1_sce3", ax=ax[1, 2])    
proj3.plot(kind='line', x="Time", y="P1_sce4",ax=ax[1, 2])    
ax[1, 2].set_xlabel("Time(Years)")
ax[1, 2].set_ylabel("Primary Producers P1")
ax[1, 2].legend(["Scenario 3","Scenario 4"])

ax[2, 0]=proj3.plot(kind='line', x="Time", y="P2_sce3", ax=ax[2, 0])    
proj3.plot(kind='line', x="Time", y="P2_sce4",ax=ax[2, 0])    
ax[2, 0].set_xlabel("Time(Years)")
ax[2, 0].set_ylabel("Primary Producers P2")
ax[2, 0].legend(["Scenario 3","Scenario 4"])

ax[2, 1]=proj3.plot(kind='line', x="Time", y="P3_sce3", ax=ax[2, 1])    
proj3.plot(kind='line', x="Time", y="P3_sce4",ax=ax[2, 1])    
ax[2, 1].set_xlabel("Time(Years)")
ax[2, 1].set_ylabel("Primary Producers P3")
ax[2, 1].legend(["Scenario 3","Scenario 4"])

ax[2, 2]=proj3.plot(kind='line', x="Time", y="C_Emission_sce3", ax=ax[2, 2])    
proj3.plot(kind='line', x="Time", y="C_Emission_sce4",ax=ax[2, 2])    
ax[2, 2].set_xlabel("Time(Years)")
ax[2, 2].set_ylabel("Carbon Emissions(kt)")
ax[2, 2].set_yscale('log')
ax[2, 2].legend(["Scenario 3","Scenario 4"])

ax[3, 0]=proj3.plot(kind='line', x="Time", y="GDP_sce3", ax=ax[3, 0])    
proj3.plot(kind='line', x="Time", y="GDP_sce4",ax=ax[3, 0])    
ax[3, 0].set_xlabel("Time(Years)")
ax[3, 0].set_ylabel("GDP (US $)")
ax[3, 0].legend(["Scenario 3","Scenario 4"])

ax[3, 1]=proj3.plot(kind='line', x="Time", y="numHH_sce3", ax=ax[3, 1])    
proj3.plot(kind='line', x="Time", y="numHH_sce4",ax=ax[3, 1])    
ax[3, 1].set_xlabel("Time(Years)")
ax[3, 1].set_ylabel("Human Population (Hundred Thousand)")
ax[3, 1].legend(["Scenario 3","Scenario 4"])
#ax[3,1].set_title('Humans')

ax[3, 2]=proj3.plot(kind='line', x="Time", y="N_Emission_sce3", ax=ax[3, 2])    
proj3.plot(kind='line', x="Time", y="N_Emission_sce4",ax=ax[3, 2]) 
ax[3, 2].set_yscale('log')
ax[3, 2].set_xlabel("Time(Years)")
ax[3, 2].legend(["Scenario 3","Scenario 4"])
plt.tight_layout()

plt.savefig('fig10.jpeg', dpi=600);
plt.show()
