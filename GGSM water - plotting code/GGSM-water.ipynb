# %% [markdown]
# # Preparation

# %% [markdown]
# ## Importing configurations and functions

# %%
# Importing the necessary functions
# Required packages are imported from the functions module
import zz_structured_code.code.local_functions.local_functions as lkl_f
import zz_structured_code.code.local_functions.our_world_in_data as owid_f
from zz_structured_code.code.config.config_parameters import *

# %% [markdown]
# # Data acquisition

# %% [markdown]
# ## Model data acquisition

# %%
from zz_structured_code.code.sectoral_intensity.data_acquisition import f_model_df

current_case = "base"  # Base case
current_case = "popex"  # Population explosion
df_model_period, df_model_complete = f_model_df(current_case)
df_model_period.head()
# Out:
#         P1   H1    ISprod    EEprod  Population
# 0  0.60052  2.5  0.000009  0.000067     27545.0
# 1  0.60058  2.5  0.000009  0.000067     27554.0
# 2  0.60064  2.5  0.000009  0.000067     27563.0
# 3  0.60070  2.5  0.000009  0.000067     27572.0
# 4  0.60076  2.5  0.000009  0.000067     27581.0

# %% [markdown]
# ## Water data acquisition

# %%
from zz_structured_code.code.sectoral_intensity.data_acquisition import f_water_df

water_data = f_water_df()
water_data.head()
# Out:
#            HH          IS           P1  center_year
# 0    23.26945     28.2815    410.35645         1970
# 1     49.2296   80.892075   923.424275         1975
# 2   74.660025  141.841788  1213.300888         1980
# 3  164.386037  348.220044  1539.257169         1985
# 4  257.381919  627.964747  1895.850509         1990

# %% [markdown]
# ## Water data processing

# %%
from zz_structured_code.code.sectoral_intensity.data_processing import (
    f_water_backward_extrapolation,
)

water_data = f_water_backward_extrapolation(water_data)
water_data.head()
# Out:
#    center_year          P1         IS         HH
# 0         1955  307.767337  21.211125  17.452088
# 1         1960  341.963708  23.567917  19.391208
# 2         1965  376.160079  25.924708  21.330329
# 3         1970   410.35645    28.2815   23.26945
# 4         1975  923.424275  80.892075    49.2296

# %%
from zz_structured_code.code.sectoral_intensity.data_plotting import (
    f_water_data_plotting,
)

f_water_data_plotting(water_data)
# Out:
# plots saved to
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/data/output/plots/general

# %%
from zz_structured_code.code.sectoral_intensity.data_processing import (
    f_water_data_discritizer,
)

df_water_data_final = f_water_data_discritizer(water_data)
df_water_data_final
# Out:
#                P1          IS          HH
# 0      307.767337   21.211125   17.452088
# 1      307.899370   21.220225   17.459574
# 2      308.031402   21.229324   17.467061
# 3      308.163434   21.238424   17.474548
# 4      308.295467   21.247523   17.482035
# ...           ...         ...         ...
# 2855  2518.965580  689.512804  434.421836
# 2856  2519.105592  689.272416  434.458865
# 2857  2519.245604  689.032027  434.495893
# 2858  2519.385616  688.791639  434.532922
# 2859  2519.525628  688.551251  434.569950
#
# [2860 rows x 3 columns]

# %% [markdown]
# # Figure 2: sectoral intensity plots

# %%
from zz_structured_code.code.sectoral_intensity.data_plotting import (
    f_sectoral_intensity_trends_plotting,
)

f_sectoral_intensity_trends_plotting(
    df_model_period, df_model_complete, df_water_data_final
)
# Out:
# plots saved to
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/data/output/plots/sectoral_intensity
# dataframes saved to
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/data/output/dataframes/sectoral_intensity

# %% [markdown]
# # Figure 3: validation

# %%
from zz_structured_code.code.sectoral_intensity.plots_validation import f_validation

f_validation(df_water_data_final)
# Out:
# plots saved to
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/data/output/plots/sectoral_intensity

# %% [markdown]
# # Geographical Distribution

# %% [markdown]
# ## Input groups

# %%
from zz_structured_code.code.geographical_distribution.input_groups import (
    f_input_groups,
)

(
    l_variable_names_all,
    l_variable_names_demand,
    df_groups,
    l_group_names,
    l_file_names,
    l_years_2013,
    l_years_2150,
    l_col_names_var_grp_year,
    l_col_names_var_grp_cntry_year,
) = f_input_groups()

# %% [markdown]
# ## Reading data and processing data

# %%
from zz_structured_code.code.geographical_distribution.data_acquisition import (
    f_df_data_with_percap,
)

df_data_with_percap = f_df_data_with_percap(
    l_file_names, l_variable_names_all, df_groups
)
df_data_with_percap.head(2)
# Out:
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/local_functions/our_world_in_data.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_local = df_local[condition_1][condition_2]
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/local_functions/our_world_in_data.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_local = df_local[condition_1][condition_2]
# Year                       Variable   Group      Country      1961      1962  \
# 0     Agricultural Area\n(hectares)    Asia  Afghanistan  4.210409  4.130387
# 1     Agricultural Area\n(hectares)  Europe      Albania  0.738167  0.716696
#
# Year      1963      1964      1965      1966      1967  ...      2004  \
# 0     4.048180  3.967005  3.878648  3.795095  3.715418  ...  1.578375
# 1     0.696217  0.675082  0.660085  0.643821  0.628600  ...  0.348881
#
# Year      2005      2006      2007      2008      2009      2010      2011  \
# 0     1.524878  1.479068  1.438764  1.402412  1.368197  1.334953  1.302560
# 1     0.336984  0.352201  0.353443  0.374089  0.381244  0.381365  0.380786
#
# Year      2012      2013
# 0     1.271081  1.240835
# 1     0.379918  0.374188
#
# [2 rows x 56 columns]

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_per_cap_to_total

df_data_complete_with_nan = f_per_cap_to_total(df_data_with_percap, l_years_2013)
df_data_complete_with_nan
# Out:
# Year                       Variable          Group              Country  \
# 0     Agricultural Area\n(hectares)           Asia          Afghanistan
# 1     Agricultural Area\n(hectares)         Europe              Albania
# 2     Agricultural Area\n(hectares)         Africa              Algeria
# 3     Agricultural Area\n(hectares)         Africa               Angola
# 4     Agricultural Area\n(hectares)  North America  Antigua and Barbuda
# ..                              ...            ...                  ...
# 871               Total Area\n(km2)           Asia           Uzbekistan
# 872               Total Area\n(km2)        Oceania              Vanuatu
# 873               Total Area\n(km2)           Asia              Vietnam
# 874               Total Area\n(km2)         Africa               Zambia
# 875               Total Area\n(km2)         Africa             Zimbabwe
#
# Year          1961          1962          1963          1964          1965  \
# 0     3.860524e+07  3.862325e+07  3.863178e+07  3.865847e+07  3.861582e+07
# 1     1.244549e+06  1.245617e+06  1.246924e+06  1.244852e+06  1.251522e+06
# 2     4.458604e+07  4.404711e+07  4.369213e+07  4.337960e+07  4.340616e+07
# 3     6.252863e+07  6.228691e+07  6.195470e+07  6.148478e+07  6.082171e+07
# 4     1.000000e+04  9.000000e+03  1.000000e+04  8.847458e+03  1.081667e+04
# ..             ...           ...           ...           ...           ...
# 871   4.254000e+05  4.254000e+05  4.254000e+05  4.254000e+05  4.254000e+05
# 872   1.219000e+04  1.219000e+04  1.219000e+04  1.219000e+04  1.219000e+04
# 873   3.254900e+05  3.254900e+05  3.254900e+05  3.254900e+05  3.254900e+05
# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_fill_missing_data

df_data_complete_updated = f_fill_missing_data(df_data_complete_with_nan, l_variable_names_all, l_years_2013)
# df_data_complete_updated
# Out:
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/geographical_distribution/data_processing.py:170: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_correction_local = df_missing_data_local.copy()[condition_1]
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/geographical_distribution/data_processing.py:170: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_correction_local = df_missing_data_local.copy()[condition_1]
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/geographical_distribution/data_processing.py:170: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_correction_local = df_missing_data_local.copy()[condition_1]
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/geographical_distribution/data_processing.py:170: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_correction_local = df_missing_data_local.copy()[condition_1]

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_agri_to_total_area_limiting_ratio
df_local = f_agri_to_total_area_limiting_ratio(df_data_complete_updated, l_group_names)
df_local
# Out:
#                    Africa       Asia     Europe  North America    Oceania  \
# Smallest ratio   7.590458   0.069593   0.666706       3.463393   1.964988
# Largest ratio   85.169617  90.555885  82.464027      77.368774  65.823555
#
#                 South America
# Smallest ratio       0.260317
# Largest ratio       93.440750

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_extrapolate_country_df

df_country_data_extrapolation = f_extrapolate_country_df(df_data_complete_updated, l_variable_names_all, l_col_names_var_grp_cntry_year)
# df_country_data_extrapolation

# %%
df_country_data_extrapolation.columns
# Out:
# Index(['Variable',    'Group',  'Country',       1961,       1962,       1963,
#              1964,       1965,       1966,       1967,
#        ...
#              2141,       2142,       2143,       2144,       2145,       2146,
#              2147,       2148,       2149,       2150],
#       dtype='object', name='Year', length=193)

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_agri_to_total_area_limiting_ratio
df_local = f_agri_to_total_area_limiting_ratio(df_country_data_extrapolation, l_group_names)
df_local
# Out:
#                     Africa        Asia      Europe  North America    Oceania  \
# Smallest ratio    0.022320    0.026898    0.008625       0.035009   0.130448
# Largest ratio   229.809982  231.307465  115.207993     138.481216  65.823555
#
#                 South America
# Smallest ratio       0.002175
# Largest ratio      127.345497

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_correcting_agri_area

f_correcting_agri_area(df_country_data_extrapolation, l_group_names, l_years_2150)
# Out:
# Year           Variable          Group         Country               1961  \
# 0     Total Area\n(km2)           Asia     Afghanistan           652860.0
# 1     Total Area\n(km2)         Europe         Albania            27400.0
# 2     Total Area\n(km2)         Africa         Algeria          2381740.0
# 3     Total Area\n(km2)        Oceania  American Samoa              200.0
# 4     Total Area\n(km2)         Europe         Andorra              470.0
# ..                  ...            ...             ...                ...
# 871          GDP\n(USD)  South America         Uruguay      17985996000.0
# 872          GDP\n(USD)           Asia      Uzbekistan  4805547761.074219
# 873          GDP\n(USD)           Asia         Vietnam      36965268000.0
# 874          GDP\n(USD)         Africa          Zambia       5438916000.0
# 875          GDP\n(USD)         Africa        Zimbabwe      10777800000.0
#
# Year               1962               1963               1964  \
# 0              652860.0           652860.0           652860.0
# 1               27400.0            27400.0            27400.0
# 2             2381740.0          2381740.0          2381740.0
# 3                 200.0              200.0              200.0
# 4                 470.0              470.0              470.0
# ..                  ...                ...                ...
# 871       18113424000.0      18086640000.0      18580380000.0
# 872   4805547761.074219  4805547761.074219  4805547761.074219
# 873       41515551000.0      42615153000.0      44503800000.0
# 874        5471958000.0       5775840000.0       6794406000.0
# 875       10646804000.0      10606302000.0      10915575000.0
#
# Year               1965               1966               1967  ...  \
# 0              652860.0           652860.0           652860.0  ...
# 1               27400.0            27400.0            27400.0  ...
# 2             2381740.0          2381740.0          2381740.0  ...
# 3                 200.0              200.0              200.0  ...
# 4                 470.0              470.0              470.0  ...
# ..                  ...                ...                ...  ...
# 871       18929680000.0      19679121000.0      18947500000.0  ...
# 872   4805547761.074219  4805547761.074219  4805547761.074219  ...
# 873       44862915000.0      45230238000.0      39592124000.0  ...
# 874        8603700000.0       7584920000.0       8416368000.0  ...
# 875       11950983000.0      11996685000.0      13192800000.0  ...
#
# Year                  2141                  2142                  2143  \
# 0                 652860.0              652860.0              652860.0
# 1                  27400.0               27400.0               27400.0
# 2                2381740.0             2381740.0             2381740.0
# 3                    200.0                 200.0                 200.0
# 4                    470.0                 470.0                 470.0
# ..                     ...                   ...                   ...
# 871    183478850891.774658   184505677722.943359   185532504554.112305
# 872   1773285448910.445312  1785349114076.730469  1797412779243.015625
# 873   2719330950906.492188  2737189533362.335938  2755048115818.179688
# 874    318860340232.034668    321011171886.57959   323162003541.125488
# 875       439446066.666748      439446066.666748      439446066.666748
#
# Year                  2144                  2145                  2146  \
# 0                 652860.0              652860.0              652860.0
# 1                  27400.0               27400.0               27400.0
# 2                2381740.0             2381740.0             2381740.0
# 3                    200.0                 200.0                 200.0
# 4                    470.0                 470.0                 470.0
# ..                     ...                   ...                   ...
# 871     186559331385.28125   187586158216.450195   188612985047.619141
# 872   1809476444409.300781  1821540109575.585938  1833603774741.871094
# 873   2772906698274.023438  2790765280729.867188  2808623863185.710938
# 874     325312835195.67041   327463666850.216309    329614498504.76123
# 875       439446066.666748      439446066.666748      439446066.666748
#
# Year                  2147                  2148                  2149  \
# 0                 652860.0              652860.0              652860.0
# 1                  27400.0               27400.0               27400.0
# 2                2381740.0             2381740.0             2381740.0
# 3                    200.0                 200.0                 200.0
# 4                    470.0                 470.0                 470.0
# ..                     ...                   ...                   ...
# 871    189639811878.787598   190666638709.956543   191693465541.125488
# 872    1845667439908.15625  1857731105074.441406  1869794770240.726562
# 873   2826482445641.554688  2844341028097.398438  2862199610553.242188
# 874    331765330159.307129   333916161813.853027   336066993468.397949
# 875       439446066.666748      439446066.666748      439446066.666748
#
# Year                  2150
# 0                 652860.0
# 1                  27400.0
# 2                2381740.0
# 3                    200.0
# 4                    470.0
# ..                     ...
# 871    192720292372.294434
# 872   1881858435407.011719
# 873   2880058193009.085938
# 874    338217825122.943848
# 875       439446066.666748
#
# [876 rows x 193 columns]

# %%
df_local.iloc[0].to_dict()
# Out:
# {'Africa': 0.02232007123529911,
#  'Asia': 0.026897575706243515,
#  'Europe': 0.008624621666967869,
#  'North America': 0.03500853478908539,
#  'Oceania': 0.13044771552085876,
#  'South America': 0.0021752093452960253}

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_agri_to_total_area_limiting_ratio
df_local = f_agri_to_total_area_limiting_ratio(df_country_data_extrapolation, l_group_names)
df_local
# Out:
#                     Africa        Asia      Europe  North America    Oceania  \
# Smallest ratio    0.022320    0.026898    0.008625       0.035009   0.130448
# Largest ratio   100.000008  100.000008  100.000000     100.000000  65.823555
#
#                 South America
# Smallest ratio       0.002175
# Largest ratio      100.000000

# %% [markdown]
# ## Group level aggregation

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_continent_aggregation

df_sum = f_continent_aggregation(df_country_data_extrapolation, 
                                 l_variable_names_all, l_col_names_var_grp_year)
df_sum.reset_index(drop=True)
# Out:
# Year                       Variable          Group          1961  \
# 0                 Total Area\n(km2)         Africa  2.554465e+07
# 1                 Total Area\n(km2)           Asia  2.820304e+07
# 2                 Total Area\n(km2)         Europe  2.206970e+07
# 3                 Total Area\n(km2)  North America  2.125993e+07
# 4                 Total Area\n(km2)        Oceania  8.485110e+06
# 5                 Total Area\n(km2)  South America  1.651303e+07
# 6                        Population         Africa  2.416120e+08
# 7                        Population           Asia  1.648392e+09
# 8                        Population         Europe  6.040140e+08
# 9                        Population  North America  2.814600e+08
# 10                       Population        Oceania  1.630000e+07
# 11                       Population  South America  1.442950e+08
# 12    Agricultural Area\n(hectares)         Africa  8.843190e+08
# 13    Agricultural Area\n(hectares)           Asia  1.253856e+09
# 14    Agricultural Area\n(hectares)         Europe  5.067838e+08
# 15    Agricultural Area\n(hectares)  North America  6.353345e+08
# 16    Agricultural Area\n(hectares)        Oceania  4.760031e+08
# 17    Agricultural Area\n(hectares)  South America  4.233308e+08
# 18        Livestock\n(meat, tonnes)         Africa  3.955737e+06
# 19        Livestock\n(meat, tonnes)           Asia  8.819026e+06
# 20        Livestock\n(meat, tonnes)         Europe  2.387034e+07
# 21        Livestock\n(meat, tonnes)  North America  1.958289e+07
# 22        Livestock\n(meat, tonnes)        Oceania  2.297833e+06
# 23        Livestock\n(meat, tonnes)  South America  6.306283e+06
# 24                       GDP\n(USD)         Africa  4.979480e+11
# 25                       GDP\n(USD)           Asia  2.559271e+12
# 26                       GDP\n(USD)         Europe  4.706710e+12
# 27                       GDP\n(USD)  North America  3.951375e+12
# 28                       GDP\n(USD)        Oceania  1.891364e+11
# 29                       GDP\n(USD)  South America  5.409237e+11
#
# Year          1962          1963          1964          1965          1966  \
# 0     2.554465e+07  2.554465e+07  2.554465e+07  2.554465e+07  2.554465e+07
# 1     2.820304e+07  2.820304e+07  2.820304e+07  2.820304e+07  2.820304e+07
# 2     2.206968e+07  2.206969e+07  2.206969e+07  2.206968e+07  2.206967e+07
# 3     2.125993e+07  2.125993e+07  2.125993e+07  2.125993e+07  2.125993e+07
# 4     8.485110e+06  8.485110e+06  8.485110e+06  8.485110e+06  8.485110e+06
# 5     1.651303e+07  1.651303e+07  1.651303e+07  1.651303e+07  1.651303e+07
# 6     2.473800e+08  2.533650e+08  2.595520e+08  2.659340e+08  2.725250e+08
# 7     1.681613e+09  1.716627e+09  1.754016e+09  1.794140e+09  1.837178e+09
# 8     6.099910e+08  6.159120e+08  6.215910e+08  6.269110e+08  6.317970e+08
# 9     2.866790e+08  2.918200e+08  2.968630e+08  3.017970e+08  3.066100e+08
# 10    1.662900e+07  1.696900e+07  1.732700e+07  1.770600e+07  1.811700e+07
# 11    1.481530e+08  1.520980e+08  1.560970e+08  1.601300e+08  1.641900e+08
# 13    34.118804  34.106706  34.094621  34.082549
# 14      7.36592   7.353239    7.34057   7.327916
# 15    10.386735  10.364377  10.342044  10.319734
# 16     0.086365    0.08638   0.086394   0.086409
# 17    18.985049  19.000151  19.015237  19.030306
# 18     5.472977   5.473688   5.474391   5.475087
# 19    47.646578  47.655357   47.66404  47.672629
# 20    13.130789  13.125025  13.119323  13.113684
# 21    15.534247   15.52569  15.517225  15.508853
# 22     1.411608   1.410163   1.408733   1.407319
# 23      16.8038  16.810077  16.816286  16.822428
# 24     4.738654    4.73951   4.740356   4.741192
# 25    49.500478  49.513631  49.526628  49.539473
# 26    21.602023   21.59636  21.590764  21.585233
# 27    17.280628  17.272151  17.263774  17.255495
# 28     1.227768   1.227609   1.227451   1.227295
# 29     5.650448   5.650739   5.651027   5.651312
#
# [30 rows x 192 columns]

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_get_df_breakpoints
df_break_points = f_get_df_breakpoints(dct_break_points, l_variable_names_demand, l_group_names)
df_break_points
# Out:
#                        Population   Agricultural Area\n(hectares)  \
# Group
# Africa               [2030, 2100]                    [2080, 2125]
# Asia           [1976, 1998, 2080]  [1976, 1994, 2014, 2045, 2120]
# Europe               [2013, 2100]                    [2025, 2100]
# North America        [1992, 2014]                    [1978, 2013]
# Oceania              [1996, 2025]                    [2100, 2120]
# South America  [1980, 2020, 2075]                    [1980, 2010]
#
#               Livestock\n(meat, tonnes)                GDP\n(USD)
# Group
# Africa               [1976, 2000, 2050]  [1974, 1988, 2000, 2014]
# Asia                       [2008, 2075]              [2030, 2075]
# Europe                     [2013, 2075]              [2025, 2075]
# North America              [2018, 2075]              [2040, 2075]
# Oceania                    [2013, 2075]        [1980, 2000, 2025]
# South America              [2050, 2075]  [1986, 2013, 2060, 2100]

# %%
from zz_structured_code.code.geographical_distribution.data_processing import f_contribution_linear_segment_fits
df_segment_equations = f_contribution_linear_segment_fits(df_percent, l_variable_names_demand, l_group_names, df_break_points)

# %%
df_segment_equations["Score"].mean()
dct_segments_equations = (
    df_segment_equations.copy()
    .set_index(["Variable", "Group", "Segment_count"])
    .to_dict(orient="index")
)

# %%
from zz_structured_code.code.geographical_distribution.plotting_functions import f_linear_plot_continent_contribution
import os
import matplotlib.pyplot as plt
from zz_structured_code.code.config.config_project_path import main_project_directory
tple_lgd = f_linear_plot_continent_contribution(df_segment_equations, df_percent, l_group_names, l_variable_names_demand)

file_name = 'main-fig-4-geographical-distribution.png'
parent_directory_path = os.path.join(
    main_project_directory,
    'data',
    'output',
    'plots',
    'continentwise_distribution'
)
file_path = os.path.join(
    parent_directory_path,
    file_name
)

plt.savefig(file_path,
            bbox_extra_artists=tple_lgd,
            bbox_inches="tight",
           )
# Out:
# ('Population', 'Oceania', 0) 0.5396611134662284
# ('Population', 'Oceania', 1) 0.5388843317968788
# ('Population', 'Oceania', 2) 0.5864972873835963
# ('Agricultural Area\n(hectares)', 'Oceania', 1) 0.10568829710314276
# ('Agricultural Area\n(hectares)', 'Oceania', 2) 0.019138056009905924

# %%
from zz_structured_code.code.geographical_distribution.plotting_functions import f_stacked_area_continent_contribution
import os
from zz_structured_code.code.config.config_project_path import main_project_directory

tple_lgd = f_stacked_area_continent_contribution(df_percent, l_group_names, l_variable_names_demand, l_variable_names_all)

file_name = 'main-fig-4-b-geographical-distribution-stacked-area.png'
parent_directory_path = os.path.join(
    main_project_directory,
    'data',
    'output',
    'plots',
    'continentwise_distribution'
)
file_path = os.path.join(
    parent_directory_path,
    file_name
)

plt.savefig(file_path,
            bbox_extra_artists=tple_lgd,
            bbox_inches="tight",
           )

# %% [markdown]
# # Figure 5: Global_demand_availability

# %%
from zz_structured_code.code.scenario_analysis.main_fig_5_Global_demand_availability import f_plot_figure

f_plot_figure()

# %% [markdown]
# # Figure 6: Regional_water_stress_dynamics

# %%
from zz_structured_code.code.scenario_analysis.main_fig_6_Regional_water_stress_dynamics import f_plot_figure

f_plot_figure()

# %% [markdown]
# # Figure 7: Regional_sectoral_analysis

# %%
from zz_structured_code.code.scenario_analysis.main_fig_7_regional_sectoral_analysis import f_plot_figure

f_plot_figure()
# Out:
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/scenario_analysis/main_fig_7_regional_sectoral_analysis.py:124: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crossing_threshold = round(df_local_plot.iloc[200:][condition_1].index[0])
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/scenario_analysis/main_fig_7_regional_sectoral_analysis.py:124: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crossing_threshold = round(df_local_plot.iloc[200:][condition_1].index[0])
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/scenario_analysis/main_fig_7_regional_sectoral_analysis.py:124: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crossing_threshold = round(df_local_plot.iloc[200:][condition_1].index[0])
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/scenario_analysis/main_fig_7_regional_sectoral_analysis.py:124: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crossing_threshold = round(df_local_plot.iloc[200:][condition_1].index[0])
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/scenario_analysis/main_fig_7_regional_sectoral_analysis.py:124: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crossing_threshold = round(df_local_plot.iloc[200:][condition_1].index[0])
# /home/neeraj/Dropbox/0_Data_Ph.D./1_PUBLICATIONS_reports/0_Journal/3-/0-Model-code-upload/GGSM water plots/Plotting-code-ipynb/zz_structured_code/code/scenario_analysis/main_fig_7_regional_sectoral_analysis.py:124: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   crossing_threshold = round(df_local_plot.iloc[200:][condition_1].index[0])

# %% [markdown]
# # Figure 8: Sectoral_regional_analysis

# %%
from zz_structured_code.code.scenario_analysis.main_fig_8_sectoral_regional_analysis import f_plot_figure

f_plot_figure()

# %% [markdown]
# # Figure 9: Population explosion

# %%
from zz_structured_code.code.scenario_analysis.main_fig_9_base_popex import f_plot_figure

f_plot_figure()
# Out:
#        Group  Base Case  Population Explosion
# 0  S-America         27                    28
# 1    Oceania        162                   162
# 2  N-America         44                    44
# 3     Europe         45                    45
# 4       Asia         86                    97
# 5     Africa        140                   149

# %% [markdown]
# # Figure 10: Reduction

# %%
from zz_structured_code.code.scenario_analysis.main_fig_10_reduction import f_plot_figure

f_plot_figure()
# Out:
#        Group  Base Case  Last timestep Base Case  Reduction 30%  \
# 0  S-America         27                       28             20
# 1    Oceania        162                       15            162
# 2  N-America         44                       41             44
# 3     Europe         45                       40             45
# 4       Asia         86                       87             75
# 5     Africa        140                      140            106
#
#    Last timestep Reduction 30%
# 0                           21
# 1                           14
# 2                           34
# 3                           34
# 4                           74
# 5                          107
